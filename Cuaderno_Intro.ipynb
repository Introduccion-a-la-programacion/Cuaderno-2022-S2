# %% [markdown]
# <a href="https://colab.research.google.com/github/Introduccion-a-la-programacion/Cuaderno-2022-S2/blob/main/Cuaderno_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Semana 1 - Pseudocódigo

# %% [markdown]
# ## Contador de dígitos
#
# Usando Pseint crear un diagrama de flujo para representar el flujo y pseudocódigo para el algoritmo de contarDigitos.
#
# - Recibirán dos parametros
# - Ambos mayores a cero

# %% [markdown]
# ### Diagrama de Flujo
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pseudocódigo
#
#
# ```
# Algoritmo contarDigitos
# 	total = 0
# 	Leer a
# 	Mientras a > 0 Hacer
# 		// Realiza la operación
# 		a = trunc(a / 10)
# 		total = total + 1
# 	FinMientras
# 	Escribir total
# FinAlgoritmo
# ```
